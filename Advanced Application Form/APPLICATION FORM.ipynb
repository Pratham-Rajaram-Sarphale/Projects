# %%
#Basic Application Form
from tkinter import *
from tkinter import messagebox as mbox
def printinfo():
    print(f"{ent1.get(),ent2.get(),ent4.get(),ent5.get(),ent6.get()}")
    
    with open("Student_details.txt","a") as sd:
        sd.write(f"My name is {ent1.get(),ent2.get(),ent4.get(),ent5.get(),ent6.get()}\n")
    submit=mbox.askquestion("Confirm", "Are you sure you want to submit?")
    if submit=='yes':
        msg='Application Submitted Successfully.'
    else: msg='Please make necessary changes.'
    mbox.showinfo('Submit',msg)
    Button(f1,text='Logout',font="Helvtica 12 bold",bg='SeaGreen1',command=prs.destroy,activeforeground='green3',padx=4,pady=1).grid(row=22,column=2)
    

def selected_item():
    for i in lb.curselection():
        print(lb.get(i))
def selected_item1():
    for i in lb1.curselection():
        print(lb1.get(i))
def selected_item2():
    for i in lb2.curselection():
        print(lb2.get(i))
def deselect():
    cb1.deselect()
    cb2.deselect()
    cb3.deselect()
    cb4.deselect()
    cb5.deselect()
    cb6.deselect()
    cb7.deselect()
    cb8.deselect()

prs=Tk()
prs.title('by-Pratham R.S')
prs.wm_iconbitmap("Aha-Soft-Standard-Portfolio-Unemployed.ico")
prs.geometry('1600x900')
prs.configure(bg='antique white')

#data types of variables
lab1value=StringVar()
lab2value=StringVar()
lab3value=StringVar()
lab4value=StringVar()
lab6value=StringVar()
rb1value=IntVar() 

Label(prs,text='EMPLOYMENT/ JOB APPLICATION',relief='groove',font='helvtica 28 bold',bg='navajo white').grid()

f1=Frame(prs)
f1.grid()
f1.configure(bg='antique white')
lab1=Label(f1,text="NAME ",font='helvtica 12 bold',bg='navajo white')
lab1.grid(row=1,column=0,sticky='w')
ent1=Entry(f1,textvariable=lab1value,justify=CENTER,width=30)
ent1.grid(row=1,column=1)

lab2=Label(f1,text="DATE OF BIRTH (DOB) ",font='helvtica 12 bold',bg='navajo white')
lab2.grid(row=2,column=0,sticky='w')


lb = Listbox(f1,bd='3',relief='groove')
lb.grid(row=2,column=1)
lb.insert(1, 'January')
lb.insert(2, 'February')
lb.insert(3, 'March')
lb.insert(4, 'April')
lb.insert(5, 'May')
lb.insert(6, 'June')
lb.insert(7, 'July')
lb.insert(8, 'August')
lb.insert(9, 'September')
lb.insert(10, 'October')
lb.insert(11, 'November')
lb.insert(12, 'December')
sb=Scrollbar(f1)
sb.grid(row=2,column=2,sticky=NS)
sb.config(command=lb.yview)
lb.config(yscrollcommand=sb.set)
Button(f1,text='Month',bg='navajo white',padx=38,font="Helvtica 10 bold",command=selected_item).grid(row=4,column=1)

lb1=Listbox(f1,bd='3',relief='groove')
lb1.grid(row=2,column=3)
for i in range(1,32):
    lb1.insert(i,i)
sb1=Scrollbar(f1)
sb1.grid(row=2,column=4,sticky=NS)
sb1.config(command=lb1.yview)
lb1.config(yscrollcommand=sb1.set)
Button(f1,text='Date',bg='navajo white',padx=42,font="Helvtica 10 bold",command=selected_item1).grid(row=4,column=3)

lb2=Listbox(f1,bd='3',relief='groove')
lb2.grid(row=2,column=5)
for i in range(2022,1962,-1):
    lb2.insert(i,i)
sb2=Scrollbar(f1)
sb2.grid(row=2,column=6,sticky=NS)
sb2.config(command=lb2.yview)
lb2.config(yscrollcommand=sb2.set)
Button(f1,text='Year',bg='navajo white',padx=42,font="Helvtica 10 bold",command=selected_item2).grid(row=4,column=5)

lab2=Label(f1,text="PRESENT ADDRESS ",bg='navajo white',font='helvtica 12 bold')
lab2.grid(row=5,column=0,sticky='w')
ent2=Entry(f1,textvariable=lab2value,justify=CENTER,width=30)
ent2.grid(row=5,column=1)

lab4=Label(f1,text="PHONE NO ",bg='navajo white',font='helvtica 12 bold')
lab4.grid(row=7,column=0,sticky='w')
ent4=Entry(f1,textvariable=lab4value,justify=CENTER,width=30)
ent4.grid(row=7,column=1)
lab6=Label(f1,text="PERSONAL INFORMATION",relief='groove',bg='navajo white',font='helvtica 20 bold')
lab6.grid(row=0,column=0)
lab61=Label(f1,text="WRITE YOUR DESCRIPTION",bg='navajo white',font='helvtica 12 bold')
lab61.grid(row=9,column=0,sticky='w')
T=Text(f1,height=3,width=40)
T.grid(row=9,column=1)


#variables data types
lab8=StringVar()
rb3value=IntVar()
rb5value=IntVar()
lab10=StringVar()

#employment desired
lab7=Label(f1,text="EMPLOYMENT DESIRED",relief='groove',bg='navajo white',font='helvtica 20 bold')
lab7.grid(row=10,column=0)
lab8=Label(f1,text="POSITION",bg='navajo white',font='helvtica 12 bold')
lab8.grid(row=11,column=0,sticky='w')
ent5=Entry(f1,textvariable=lab8,justify=CENTER,width=30)
ent5.grid(row=11,column=1)

lab9=Label(f1,text="ARE YOU EMPLOYED NOW ",bg='navajo white',font='helvtica 12 bold')
lab9.grid(row=12,column=0,sticky='w')
rb3=Radiobutton(f1,text="Yes",bg='navajo white',variable=rb3value,value=1)
rb3.grid(row=12,column=1)
rb4=Radiobutton(f1,text="No",bg='navajo white',variable=rb3value,value=2)
rb4.grid(row=12,column=2)
lab6=Label(f1,text="EVER APPLIED TO THIS COMPANY BEFORE",bg='navajo white',font='helvtica 12 bold')
lab6.grid(row=13,column=0,sticky='w')
rb5=Radiobutton(f1,text="Yes",bg='navajo white',variable=rb5value,value=1)
rb5.grid(row=13,column=1)
rb6=Radiobutton(f1,text="No",bg='navajo white',variable=rb5value,value=2)
rb6.grid(row=13,column=2)
lab10=Label(f1,text="REFERRED BY",bg='navajo white',font='helvtica 12 bold')
lab10.grid(row=14,column=0,sticky='w')
ent6=Entry(f1,textvariable=lab10,justify=CENTER,width=30)
ent6.grid(row=14,column=1)

#Job type
rb6value=IntVar()
lab7=Label(f1,text="JOB TYPE",relief='groove',bg='navajo white',font='helvtica 20 bold')
lab7.grid(row=15,column=0)
lab7=Label(f1,text="DAYS /HOURS AVAILABLE TO WORK",bg='navajo white',font='helvtica 12 bold')
lab7.grid(row=16,column=0,sticky='w')
cb1=Checkbutton(f1,text='I have no prefrence',bg='navajo white',height=1,width=16)
cb1.grid(row=16,column=1)
cb2=Checkbutton(f1,text='Monday',bg='navajo white',height=1,width=16)
cb2.grid(row=16,column=2)
cb3=Checkbutton(f1,text='Thursday',bg='navajo white',height=1,width=16)
cb3.grid(row=16,column=3)
cb4=Checkbutton(f1,text='Saturday',bg='navajo white',height=1,width=16)
cb4.grid(row=17,column=1)
cb5=Checkbutton(f1,text='Tuesday',bg='navajo white',height=1,width=16)
cb5.grid(row=17,column=2)
cb6=Checkbutton(f1,text='Friday',bg='navajo white',height=1,width=16)
cb6.grid(row=17,column=3)
cb7=Checkbutton(f1,text='Sunday',bg='navajo white',height=1,width=16)
cb7.grid(row=18,column=1)
cb8=Checkbutton(f1,text='Wednesday',bg='navajo white',height=1,width=16)
cb8.grid(row=18,column=2)
Button(f1,text='Clear Selection',bg='navajo white',relief='raised',bd='1',command=deselect).grid(row=20,column=2)
lab7=Label(f1,text="I AM SEEKING A:",bg='navajo white',font='helvtica 12 bold')
lab7.grid(row=21,column=0,sticky='w')
Radiobutton(f1,text='Full-time job',bg='navajo white',variable=rb6value,value=1).grid(row=21,column=1)
Radiobutton(f1,text='Part-time job',bg='navajo white',variable=rb6value,value=2).grid(row=21,column=2)
Radiobutton(f1,text='Full-or Part-time',bg='navajo white',variable=rb6value,value=3).grid(row=21,column=3)


#Declaration part
lab8=Label(f1,text='''I certify that the facts set forth in this Application for Employment are true 
and complete to the best of my knowledge. I understand that if I am employed, false statements, omissions or misrepresentations 
may result in my dismissal. Therefore, any employee (regular, temporary, or other type of category employee) may resign 
at any time, just as the employer may terminate the employment relationship with any employee at any time, 
with or without cause, with or without notice to the other party.''',font='helvtica 8 bold',bg='navajo white')
lab8.grid(row=22,column=0)
cb9=Checkbutton(f1,text='I agree to the terms and conditions',width=28,font='helvtica 8 bold',bg='navajo white')
cb9.grid(row=22,column=1)

#submission part
b1=Button(f1,text='SUBMIT',font="Helvtica 12 bold",bg='SeaGreen1',command=printinfo,activeforeground='red')
b1.grid(row=22,column=2)


prs.mainloop()
# Out:
# January
# 21
# 2002
# ('Pratham', 'Mumbai', '0000097928', 'Senior Manager', 'Linkedin')
